# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

from fastai.vision import *

#from fastai.metrics import error_rate
import pandas as pd
import numpy as np
from pathlib import Path

# %%
path = Path('data/')
path.ls()
# Out:
# [PosixPath('data/4_low_density_polyethylene_PE-LD'),
#  PosixPath('data/8_no_plastic'),
#  PosixPath('data/3_polyvinylchloride_PVC'),
#  PosixPath('data/1_polyethylene_PET'),
#  PosixPath('data/6_polystyrene_PS'),
#  PosixPath('data/5_polypropylene_PP'),
#  PosixPath('data/7_other_resins'),
#  PosixPath('data/2_high_density_polyethylene_PE-HD')]

# %%
bs=32
tfms=ds_tfms=get_transforms(do_flip=False, max_rotate=0, max_zoom=1, max_lighting=0, max_warp=0)

# %%
np.random.seed(42)
data = (ImageList.from_folder(path)
        .split_by_rand_pct(0.2)
        .label_from_folder()
        .transform(tfms, size=128)
        .databunch())

# %%
data.show_batch(rows=3, figsize=(9,7))

# %%
classes = data.classes
print(classes)
# Out:
# ['1_polyethylene_PET', '2_high_density_polyethylene_PE-HD', '3_polyvinylchloride_PVC', '4_low_density_polyethylene_PE-LD', '5_polypropylene_PP', '6_polystyrene_PS', '7_other_resins', '8_no_plastic']

# %%
from fastai.vision.learner import create_cnn,models
from fastai.vision import error_rate

# %%
learn = cnn_learner(data, models.resnet50,  metrics=error_rate)

# %%
learn.lr_find()
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='11' class='' max='13' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       84.62% [11/13 19:30<03:32]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>3.524937</td>
#       <td>#na#</td>
#       <td>01:46</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>3.566807</td>
#       <td>#na#</td>
#       <td>01:42</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>3.558149</td>
#       <td>#na#</td>
#       <td>01:45</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>3.499325</td>
#       <td>#na#</td>
#       <td>01:44</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>3.351068</td>
#       <td>#na#</td>
#       <td>01:54</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>3.063862</td>
#       <td>#na#</td>
#       <td>02:17</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>2.708549</td>
#       <td>#na#</td>
#       <td>01:41</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>2.322780</td>
#       <td>#na#</td>
#       <td>01:39</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>2.062243</td>
#       <td>#na#</td>
#       <td>01:39</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>2.339937</td>
#       <td>#na#</td>
#       <td>01:39</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>6.608047</td>
#       <td>#na#</td>
#       <td>01:39</td>
#     </tr>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='8' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/8 00:00<00:00]
#     </div>
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn.recorder.plot()

# %%
learn.fit_one_cycle(4, slice(1e-03,4e-3))
learn.save('plastics_save_1', return_path=True)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>2.906040</td>
#       <td>3.039341</td>
#       <td>0.693431</td>
#       <td>02:08</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.999448</td>
#       <td>2.479168</td>
#       <td>0.518248</td>
#       <td>02:06</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.457627</td>
#       <td>1.918691</td>
#       <td>0.430657</td>
#       <td>02:04</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.127035</td>
#       <td>1.817397</td>
#       <td>0.423358</td>
#       <td>02:05</td>
#     </tr>
#   </tbody>
# </table>
# PosixPath('data/models/plastics_save_1.pth')

# %%
learn.unfreeze()
learn.lr_find()
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='8' class='' max='13' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       61.54% [8/13 17:02<10:38]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.410898</td>
#       <td>#na#</td>
#       <td>02:06</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.388404</td>
#       <td>#na#</td>
#       <td>02:06</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.370402</td>
#       <td>#na#</td>
#       <td>02:04</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.327618</td>
#       <td>#na#</td>
#       <td>02:04</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.275455</td>
#       <td>#na#</td>
#       <td>02:14</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.246614</td>
#       <td>#na#</td>
#       <td>02:05</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.486711</td>
#       <td>#na#</td>
#       <td>02:11</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.899995</td>
#       <td>#na#</td>
#       <td>02:08</td>
#     </tr>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='1' class='' max='8' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       12.50% [1/8 00:15<01:51 0.9376]
#     </div>
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn.recorder.plot()

# %%
learn.fit_one_cycle(6, slice(1e-03,3e-4))
learn.save('plastics_save_2', return_path=True)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.421069</td>
#       <td>2.012334</td>
#       <td>0.437956</td>
#       <td>02:33</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.581414</td>
#       <td>5.094335</td>
#       <td>0.583942</td>
#       <td>02:29</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.703889</td>
#       <td>7.309214</td>
#       <td>0.678832</td>
#       <td>02:30</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.655194</td>
#       <td>3.173423</td>
#       <td>0.430657</td>
#       <td>02:30</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.570136</td>
#       <td>1.803164</td>
#       <td>0.357664</td>
#       <td>02:30</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.485523</td>
#       <td>1.402180</td>
#       <td>0.328467</td>
#       <td>02:36</td>
#     </tr>
#   </tbody>
# </table>
# PosixPath('data/models/plastics_save_2.pth')

# %%
learn.recorder.plot_losses()

# %%
interp = ClassificationInterpretation.from_learner(learn)

# %%
from sklearn.metrics import classification_report

# %%
interp.plot_confusion_matrix()

# %%
interp.most_confused()
# Out:
# [('6_polystyrene_PS', '5_polypropylene_PP', 5),
#  ('1_polyethylene_PET', '2_high_density_polyethylene_PE-HD', 3),
#  ('1_polyethylene_PET', '5_polypropylene_PP', 3),
#  ('4_low_density_polyethylene_PE-LD', '1_polyethylene_PET', 3),
#  ('1_polyethylene_PET', '8_no_plastic', 2),
#  ('2_high_density_polyethylene_PE-HD', '7_other_resins', 2),
#  ('4_low_density_polyethylene_PE-LD', '5_polypropylene_PP', 2),
#  ('5_polypropylene_PP', '8_no_plastic', 2),
#  ('6_polystyrene_PS', '1_polyethylene_PET', 2),
#  ('7_other_resins', '4_low_density_polyethylene_PE-LD', 2),
#  ('8_no_plastic', '1_polyethylene_PET', 2),
#  ('1_polyethylene_PET', '3_polyvinylchloride_PVC', 1),
#  ('1_polyethylene_PET', '6_polystyrene_PS', 1),
#  ('2_high_density_polyethylene_PE-HD', '1_polyethylene_PET', 1),
#  ('2_high_density_polyethylene_PE-HD', '4_low_density_polyethylene_PE-LD', 1),
#  ('2_high_density_polyethylene_PE-HD', '5_polypropylene_PP', 1),
#  ('2_high_density_polyethylene_PE-HD', '6_polystyrene_PS', 1),
#  ('3_polyvinylchloride_PVC', '1_polyethylene_PET', 1),
#  ('3_polyvinylchloride_PVC', '8_no_plastic', 1),
#  ('4_low_density_polyethylene_PE-LD', '7_other_resins', 1),
#  ('4_low_density_polyethylene_PE-LD', '8_no_plastic', 1),
#  ('5_polypropylene_PP', '1_polyethylene_PET', 1),
#  ('5_polypropylene_PP', '2_high_density_polyethylene_PE-HD', 1),
#  ('5_polypropylene_PP', '4_low_density_polyethylene_PE-LD', 1),
#  ('7_other_resins', '1_polyethylene_PET', 1),
#  ('7_other_resins', '3_polyvinylchloride_PVC', 1),
#  ('7_other_resins', '5_polypropylene_PP', 1),
#  ('8_no_plastic', '4_low_density_polyethylene_PE-LD', 1)]

# %%
interp.plot_top_losses(9)

# %%
learn.show_results(rows=3, figsize=(10,10))

# %%
learn.export()
